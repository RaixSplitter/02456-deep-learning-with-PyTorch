# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Problem:
# To examine the impact of recent vegetarian and vegan trends on the production of vegetarian and meat products.
#
# Hypothesis:
# We expect the meat product production to have lost some momentum and the vegetarian product production to have gained some momentum in recent years.
#
# Disclaimer:
# To keep the problem simple we limit the meat products to just meat, and the vegetarian products to be vegetables.
#
# First let's look at the trends for the UK between 2010-2021.
# plot, meat production
# plot, vegetarian production
#
# Compare
#
# Look at emmisions for the two
# plot, meat emmisions
# plot, vegetarian emmisions
#
# Suggest solutions
# plot, meat losses
# plot, meat exports and imports [Discuss wether or not Brexit could have had an impact]
#
# Take the problem globally
# plot, global meat production
# plot, global meat emmisions
#
# Point out the sinners

# %%
fb_df = pd.read_csv('FoodBalance_Europe.csv')

# %%
em_df = pd.read_csv('Emissions_Europe.csv')

# %%
em_df.Item.unique()
# Out:
# array(['Crop Residues', 'Rice Cultivation', 'Burning - Crop residues',
#        'Enteric Fermentation', 'Manure Management',
#        'Manure left on Pasture', 'Manure applied to Soils',
#        'Synthetic Fertilizers', 'Drained organic soils',
#        'Drained organic soils (CO2)', 'Drained organic soils (N2O)',
#        'On-farm energy use', 'Forestland', 'Net Forest conversion',
#        'Savanna fires', 'Fires in organic soils', 'Forest fires',
#        'Fires in humid tropical forests',
#        'Agrifood Systems Waste Disposal', 'Pesticides Manufacturing',
#        'Food Processing', 'Food Packaging', 'Food Retail',
#        'Food Household Consumption', 'Food Transport', 'Energy', 'IPPU',
#        'Waste', 'Other', 'Fertilizers Manufacturing'], dtype=object)

# %%
em_df
# Out:
#       Area Code          Area  Item Code           Item  Element Code  \
# 0             3       Albania       5064  Crop Residues          7234
# 1             3       Albania       5064  Crop Residues          7236
# 2             3       Albania       5064  Crop Residues          7230
# 3             3       Albania       5064  Crop Residues        724313
# 4             3       Albania       5064  Crop Residues        723113
# ...         ...           ...        ...            ...           ...
# 7964        248  Yugoslav SFR       6819          Other          7230
# 7965        248  Yugoslav SFR       6819          Other          7273
# 7966        248  Yugoslav SFR       6819          Other        724413
# 7967        248  Yugoslav SFR       6819          Other        724313
# 7968        248  Yugoslav SFR       6819          Other        723113
#
#                                Element Unit    Y1961    Y1962    Y1963  ...  \
# ...

# %%
fb_df_meat = fb_df[fb_df['Item'].str.contains('Meat')]

# %%
fb_df_meat = fb_df_meat[fb_df_meat['Element'] == 'Production']

# %%
fb_df_meat['Element'].unique()
# Out:
# array(['Production', 'Import Quantity', 'Stock Variation',
#        'Export Quantity', 'Domestic supply quantity', 'Losses',
#        'Residuals', 'Food', 'Food supply quantity (kg/capita/yr)',
#        'Food supply (kcal/capita/day)', 'Food supply (kcal)',
#        'Protein supply quantity (g/capita/day)',
#        'Protein supply quantity (t)',
#        'Fat supply quantity (g/capita/day)', 'Fat supply quantity (t)',
#        'Feed', 'Processing', 'Tourist consumption',
#        'Other uses (non-food)'], dtype=object)

# %%
sns.barplot(x = fb_df_meat['Area'], y = fb_df_meat['Y2021'])
plt.xticks(rotation=90)
plt.show()

# %%
fb_df_meat['Y2021'].plot(kind='bar', x='Area', y='Value')
# Out:
# <Axes: >

# %%
fb_df_meat
# Out:
#        Area Code                                               Area  \
# 218            3                                            Albania
# 533           11                                            Austria
# 854           57                                            Belarus
# 1183         255                                            Belgium
# 1504          80                             Bosnia and Herzegovina
# 1817          27                                           Bulgaria
# 2146          98                                            Croatia
# 2474         167                                            Czechia
# 2799          54                                            Denmark
# 3121          63                                            Estonia
# 3440          67                                            Finland
# 3753          68                                             France
# 4094          79                                            Germany
# ...
